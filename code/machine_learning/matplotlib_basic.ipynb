# %%
import matplotlib.pyplot as plt

# %%
import numpy

# %%
myarray = numpy.array([1,2,3])

# %%
plt.plot(myarray)

# %%
plt.xlabel('some x axis')
# Out:
# Text(0.5, 0, 'some x axis')

# %%
plt.ylabel('some y axis')
# Out:
# Text(0, 0.5, 'some y axis')

# %%
plt.show()
